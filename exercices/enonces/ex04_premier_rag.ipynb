# %% [markdown]
# # Exercice 04 — Ton premier RAG
#
# **Module concerné :** Jour 1 — Module 4 (RAG Local)
# **Durée estimée :** 30 minutes
#
# ## Contexte
# Construire ta propre chaîne RAG complète à partir de zéro, sans recopier le code du module.
#
# ## Consigne
#
# 1. Recharger l'index Chroma persisté (`/workspace/data/chroma_db_v2` du Module 5 — déjà construit en cours).
# 2. Créer un retriever avec `k=3`.
# 3. Construire un `ChatPromptTemplate` avec :
#    - un system prompt qui force le LLM à répondre **uniquement** depuis le contexte,
#    - le contexte injecté dans `{context}`,
#    - la question utilisateur dans `{question}`.
# 4. Assembler la chaîne RAG en LCEL pur.
# 5. Tester sur les 4 questions ci-dessous.
# 6. Pour **chaque** question, afficher :
#    - les sources des documents récupérés (`metadata["source"]`),
#    - la réponse du LLM.
#
# ## Questions à tester
# ```python
# questions = [
#     "Comment puis-je activer le MFA ?",
#     "Que faire si l'imprimante affiche des pages blanches ?",
#     "Le VPN GlobalProtect ne se connecte pas, par où commencer ?",
#     "Quel est le numéro de téléphone du PDG ?",  # piège : pas dans la KB !
# ]
# ```
#
# ## Critères de réussite
# - Les 3 premières questions ont une réponse cohérente avec la KB.
# - La 4e question fait dire au LLM **qu'il ne sait pas** (pas d'invention).
# - Pour chaque question, on voit clairement quelles sources ont été utilisées.
#
# ## Bonus
# Mesure le temps d'exécution de chaque question (utilise `time.perf_counter()`).
# Quelle est l'étape la plus lente : retriever, LLM, parser ?
#
# ---
#
# *Solution : `exercices/solutions/ex04_premier_rag_SOLUTION.ipynb`.*

# %%
# Ton code ici

# %%
# Ton code ici

# %%
# Ton code ici
