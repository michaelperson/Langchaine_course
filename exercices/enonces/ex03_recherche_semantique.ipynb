# %% [markdown]
# # Exercice 03 — Mini moteur de recherche sémantique
#
# **Module concerné :** Jour 1 — Module 3 (Embeddings & ChromaDB)
# **Durée estimée :** 25 minutes
#
# ## Contexte
# Tu veux comparer la **recherche par mots-clés** (naïve) à la **recherche sémantique** (embeddings) sur un mini-corpus de FAQ.
#
# ## Consigne
#
# 1. Créer le corpus suivant en mémoire (liste de tuples `(id, texte)`).
# 2. Implémenter une fonction `recherche_naive(corpus, requete)` qui retourne les entrées contenant la requête en sous-chaîne (insensible à la casse).
# 3. Indexer le même corpus dans une collection Chroma `"faq"`.
# 4. Implémenter `recherche_semantique(vectorstore, requete, k=3)`.
# 5. Comparer les résultats des 2 fonctions sur 3 requêtes (voir ci-dessous).
#
# ## Données de test
# ```python
# corpus = [
#     ("FAQ-001", "Comment réinitialiser le mot de passe de ma session Windows ?"),
#     ("FAQ-002", "Mon écran ne s'allume pas, que faire ?"),
#     ("FAQ-003", "L'imprimante du couloir affiche 'erreur de bourrage'."),
#     ("FAQ-004", "Le wifi de la salle B201 est instable depuis ce matin."),
#     ("FAQ-005", "Excel plante quand j'ouvre un fichier de plus de 100 Mo."),
#     ("FAQ-006", "Comment activer l'authentification à deux facteurs (MFA) ?"),
#     ("FAQ-007", "Le câble HDMI de mon écran ne tient plus, peut-on me le remplacer ?"),
#     ("FAQ-008", "Sage X3 refuse ma connexion ce matin."),
# ]
#
# requetes = [
#     "le moniteur affiche du noir",     # mot-clé : aucun match -> sémantique : devrait trouver FAQ-002
#     "mon password ne marche plus",     # mot-clé : aucun match -> sémantique : FAQ-001
#     "l'imprimante coince",             # mot-clé : "imprimante" partiel -> sémantique : FAQ-003
# ]
# ```
#
# ## Critères de réussite
# - Pour chaque requête, afficher les top-3 résultats des **deux méthodes** côte à côte.
# - La recherche sémantique doit trouver le bon résultat même quand la naïve échoue.
#
# ## Bonus
# Calcule un score de "rappel" : pour chaque requête, vérifie si le résultat attendu est dans le top-3 — quelle méthode gagne ?
#
# ---
#
# *Solution : `exercices/solutions/ex03_recherche_semantique_SOLUTION.ipynb`.*

# %%
# Ton code ici

# %%
# Ton code ici

# %%
# Ton code ici
